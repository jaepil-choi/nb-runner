# %% [markdown]
# # Mount Google Drive

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# import warnings
# warnings.filterwarnings('ignore')

# %%
import os
from dotenv import load_dotenv

load_dotenv()

user_key = os.getenv('USER_KEY')
data_apikey = os.getenv('DATA_API_KEY')

# %% [markdown]
# # Get Data

# %%
####  Don't touch this shell ####

import requests
import pandas as pd

def fetch_candlestick_data_coinapi(data_apikey, symbol, timeframe='1min', startDate=None, endDate=None, tradeType='future'):

    # future URL
    if tradeType == 'future':
      url = f'https://crypto.fin.cloud.ainode.ai/{data_apikey}/get/candlestick/future/{timeframe}?exchange_nm=bitget&symbol={symbol}&startDate={startDate}'

    # Add to URL if endDate is not None
    if endDate is not None:
        url += f'&endDate={endDate}'
    df = pd.DataFrame(requests.get(url).json()['data'])
    df.drop(['exchange_nm','symbol'], axis = 1, inplace = True)
    df['date'] = pd.to_datetime(df['date']).dt.strftime('%Y-%m-%d %H:%M:%S')
    df = df.set_index('date')
    return df

# %%
from datetime import datetime, timedelta

#### Don't touch
symbols = ['BTCUSDT', 'ETHUSDT', 'XRPUSDT', 'BCHUSDT', 'LTCUSDT', 'ADAUSDT', 'ETCUSDT', 'TRXUSDT', 'DOTUSDT'] # Fixed variable for verify test
timeframe = '1min' # Current fixed variable
startDate = (datetime.now().date() - timedelta(days=2)).strftime('%Y-%m-%d') # Fixed variable for verify test
endDate = (datetime.now().date() - timedelta(days=1)).strftime('%Y-%m-%d') # Fixed variable for verify test
tradeType = 'future' # Current fixed variable

df = pd.DataFrame()
for symbol in symbols:
    new = fetch_candlestick_data_coinapi(data_apikey, symbol, timeframe, startDate, endDate, tradeType)
    df = pd.concat([df,new.close], axis = 1)

df.columns = symbols
df
# Out:
#                       BTCUSDT  ETHUSDT  XRPUSDT  BCHUSDT  LTCUSDT  ADAUSDT  \
# 2025-06-21 00:00:00  103948.2  2491.79   2.1356   482.97    83.92   0.5842
# 2025-06-21 00:01:00  103925.2  2490.20   2.1330   482.74    83.77   0.5834
# 2025-06-21 00:02:00  104104.7  2494.86   2.1376   483.87    84.02   0.5844
# 2025-06-21 00:03:00  104142.0  2494.58   2.1389   484.15    83.94   0.5854
# 2025-06-21 00:04:00  104102.3  2494.43   2.1390   483.93    83.92   0.5848
# ...                       ...      ...      ...      ...      ...      ...
# 2025-06-22 23:55:00   99530.9  2200.66   1.9531   454.72    78.64   0.5307
# 2025-06-22 23:56:00   99387.6  2196.40   1.9480   454.89    78.52   0.5294
# 2025-06-22 23:57:00   99418.1  2197.20   1.9478   453.45    78.50   0.5293
# 2025-06-22 23:58:00   99474.3  2199.51   1.9493   454.05    78.60   0.5298
# 2025-06-22 23:59:00   99597.4  2200.33   1.9511   454.57    78.60   0.5306
#
#                      ETCUSDT  TRXUSDT  DOTUSDT
# ...

# %% [markdown]
# # Verify your strategy

# %%
# append your path for strategy, config file
import sys
sys.path.append('/content/drive/MyDrive/~~~~')  # Replace with your own path to the folder containing the module

# %%
# example strategy, config
import strategy_name as strategy     # Replace with your own strategy file
import strategy_name_config as config  # Replace with your own config file

# run to verify strategy
config_dict = {'strategy_config': config.strategy_config}
long_candidate, short_candidate = strategy.strategy(df, config_dict)
print(f'long_candidate symbol : {long_candidate}')
print(f'short_candidate symbol : {short_candidate}')
